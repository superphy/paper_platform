# %%
# Basic setup for displaying bokeh plots in jupyter.
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show
# Additional requirements for Stacked Bar plot.
from bokeh.core.properties import value
from bokeh.models import ColumnDataSource
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7ca71326-1003-4784-aed2-c65d7262d5d1">Loading BokehJS ...</span>
#     </div>

# %%
# NumPy imports.
import numpy as np
import cPickle as pickle
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/kevin/dev/nml/paper_platform/scripts

# %%
# Raw data.
raws = pickle.load(open('2018-04-03-12-43-15-604115_singlerun_5.p', 'rb'))
print(type(raws))
print(len(raws))
print(raws[0])
# Out:
# <type 'list'>
# 5
# [{u'job_ptstx1_datastruct': [u'Tue, 03 Apr 2018 16:44:01 GMT', u'Tue, 03 Apr 2018 16:44:04 GMT', 3.0]}, {u'job_amr_dict': [u'Tue, 03 Apr 2018 16:47:57 GMT', u'Tue, 03 Apr 2018 16:47:57 GMT', 0.0]}, {u'job_ectyper_beautify_serotype': [u'Tue, 03 Apr 2018 16:43:46 GMT', u'Tue, 03 Apr 2018 16:43:47 GMT', 1.0]}, {u'job_ectyper_beautify_vf': [u'Tue, 03 Apr 2018 16:43:40 GMT', u'Tue, 03 Apr 2018 16:43:42 GMT', 2.0]}, {u'job_ectyper_datastruct_vf': [u'Tue, 03 Apr 2018 16:43:40 GMT', u'Tue, 03 Apr 2018 16:43:43 GMT', 3.0]}, {u'job_pteae': [u'Tue, 03 Apr 2018 16:44:00 GMT', u'Tue, 03 Apr 2018 16:46:56 GMT', 176.0]}, {u'job_ptstx1_dict': [u'Tue, 03 Apr 2018 16:44:00 GMT', u'Tue, 03 Apr 2018 16:44:01 GMT', 1.0]}, {u'job_ectyper_serotype': [u'Tue, 03 Apr 2018 16:43:30 GMT', u'Tue, 03 Apr 2018 16:43:46 GMT', 16.0]}, {u'job_pteae_dict': [u'Tue, 03 Apr 2018 16:46:56 GMT', u'Tue, 03 Apr 2018 16:46:57 GMT', 1.0]}, {u'job_ptstx1_beautify': [u'Tue, 03 Apr 2018 16:44:01 GMT', u'Tue, 03 Apr 2018 16:44:04 GMT', 3.0]}, {u'job_ptstx2_datastruct': [u'Tue, 03 Apr 2018 16:44:06 GMT', u'Tue, 03 Apr 2018 16:44:07 GMT', 1.0]}, {u'job_pteae_beautify': [u'Tue, 03 Apr 2018 16:46:57 GMT', u'Tue, 03 Apr 2018 16:46:59 GMT', 2.0]}, {u'job_turtle': [u'Tue, 03 Apr 2018 16:43:28 GMT', u'Tue, 03 Apr 2018 16:43:29 GMT', 1.0]}, {u'job_id': [u'Tue, 03 Apr 2018 16:43:28 GMT', u'Tue, 03 Apr 2018 16:43:30 GMT', 2.0]}, {u'job_ectyper_vf': [u'Tue, 03 Apr 2018 16:43:30 GMT', u'Tue, 03 Apr 2018 16:43:40 GMT', 10.0]}, {u'job_amr_beautify': [u'Tue, 03 Apr 2018 16:47:57 GMT', u'Tue, 03 Apr 2018 16:47:59 GMT', 2.0]}, {u'job_ectyper_datastruct_serotype': [u'Tue, 03 Apr 2018 16:43:46 GMT', u'Tue, 03 Apr 2018 16:43:47 GMT', 1.0]}, {u'job_ptstx2': [u'Tue, 03 Apr 2018 16:43:43 GMT', u'Tue, 03 Apr 2018 16:44:04 GMT', 21.0]}, {u'job_ptstx1': [u'Tue, 03 Apr 2018 16:43:43 GMT', u'Tue, 03 Apr 2018 16:44:00 GMT', 17.0]}, {u'job_amr': [u'Tue, 03 Apr 2018 16:43:30 GMT', u'Tue, 03 Apr 2018 16:47:57 GMT', 267.0]}, {u'job_amr_datastruct': [u'Tue, 03 Apr 2018 16:47:57 GMT', u'Tue, 03 Apr 2018 16:47:58 GMT', 1.0]}, {u'job_ptstx2_dict': [u'Tue, 03 Apr 2018 16:44:04 GMT', u'Tue, 03 Apr 2018 16:44:05 GMT', 1.0]}, {u'job_qc': [u'Tue, 03 Apr 2018 16:43:25 GMT', u'Tue, 03 Apr 2018 16:43:28 GMT', 3.0]}, {u'job_pteae_datastruct': [u'Tue, 03 Apr 2018 16:46:57 GMT', u'Tue, 03 Apr 2018 16:46:59 GMT', 2.0]}, {u'job_ptstx2_beautify': [u'Tue, 03 Apr 2018 16:44:06 GMT', u'Tue, 03 Apr 2018 16:44:07 GMT', 1.0]}, {u'total': [u'Tue, 03 Apr 2018 16:43:25 GMT', u'Tue, 03 Apr 2018 16:47:59 GMT', 274.0]}]

# %%
# Data.
fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'] # list_sizes
years = ["2015", "2016", "2017"] # subtasks
colors = ["#c9d9d3", "#718dbf", "#e84d60"]

data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 4, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

source = ColumnDataSource(data=data)

# %%
# Plot.
p = figure(x_range=fruits,
           plot_height=350,
           title="Runtimes for Analysis Modules",
           x_axis_label="#Total Batch Size",
           y_axis_label="Average Runtime per Genome (seconds)",
           toolbar_location=None,
           tools="")

p.vbar_stack(years, x='fruits', width=0.9, color=colors, source=source,
             legend=[value(x) for x in years])

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
